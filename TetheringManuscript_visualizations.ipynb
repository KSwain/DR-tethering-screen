# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# initialise data of sort counts pab1:
Pab1 = {'gate':['Far Left', 'Left', 'Right', 'Far Right'], 'Counts':[0, 0, 0, 1984]} 
  
# Creates pandas DataFrame. 
dPab1 = pd.DataFrame(Pab1, index =['Far Left', 'Left', 'Right', 'Far Right']) 
  
# print the data 
dPab1
# Out:
#                 gate  Counts
# Far Left    Far Left       0
# Left            Left       0
# Right          Right       0
# Far Right  Far Right    1984

# %%
f, ax = plt.subplots(figsize=(8, 12))
ax = sns.barplot(x="gate", y="Counts", data=dPab1, color='lemonchiffon')


ax1 = ax.axhline(0, color="darkgray", ls='--')

plt.xlabel("FACS bin", fontsize=24)
plt.ylabel("Sequencing read count", fontsize=24)
#plt.ylim(-2, 0.5)
plt.xticks(fontsize=20)
plt.yticks(fontsize=15)
sns.despine(top=True, right=True)



plt.savefig("Pab1_countdata.png", format='png',dpi=300, bbox_inches='tight')
plt.show()

# %%
# initialise data of sort counts pab1:
Cth1 = {'gate':['Far Left', 'Left', 'Right', 'Far Right'], 'Counts':[2718, 0, 0, 0]} 
  
# Creates pandas DataFrame. 
dCth1 = pd.DataFrame(Cth1, index =['Far Left', 'Left', 'Right', 'Far Right']) 
  
# print the data 
dCth1
# Out:
#                 gate  Counts
# Far Left    Far Left    2718
# Left            Left       0
# Right          Right       0
# Far Right  Far Right       0

# %%
f, ax = plt.subplots(figsize=(8, 12))
ax = sns.barplot(x="gate", y="Counts", data=dCth1, color='lightcoral')


ax1 = ax.axhline(0, color="darkgray", ls='--')

plt.xlabel("FACS bin", fontsize=24)
plt.ylabel("Sequencing read count", fontsize=24)
#plt.ylim(-2, 0.5)
plt.xticks(fontsize=20)
plt.yticks(fontsize=15)
sns.despine(top=True, right=True)



plt.savefig("Cth11_countdata.png", format='png',dpi=300, bbox_inches='tight')
plt.show()

# %%
# initialise data of sort counts pab1:
Ebs1 = {'gate':['Far Left', 'Left', 'Right', 'Far Right'], 'Counts':[1217,0,3,2]} 
  
# Creates pandas DataFrame. 
dEbs1 = pd.DataFrame(Ebs1, index =['Far Left', 'Left', 'Right', 'Far Right']) 
  
# print the data 
dEbs1
# Out:
#                 gate  Counts
# Far Left    Far Left    1217
# Left            Left       0
# Right          Right       3
# Far Right  Far Right       2

# %%
f, ax = plt.subplots(figsize=(12,8))
ax = sns.barplot(x="gate", y="Counts", data=dEbs1, color='lightcoral')


ax1 = ax.axhline(0, color="darkgray", ls='--')

plt.xlabel("FACS bin", fontsize=36)
plt.ylabel("Sequencing read count", fontsize=36)
#plt.ylim(-2, 0.5)
plt.xticks(fontsize=32)
plt.yticks(fontsize=30)
sns.despine(top=True, right=True)



plt.savefig("Ebs1_countdata.png", format='png',dpi=300, bbox_inches='tight')
plt.show()

# %%
# initialise data of sort counts pab1:
Sbp1 = {'gate':['Far Left', 'Left', 'Right', 'Far Right'], 'Counts':[39,2,11,1179]} 
  
# Creates pandas DataFrame. 
dSbp1 = pd.DataFrame(Sbp1, index =['Far Left', 'Left', 'Right', 'Far Right']) 
  
# print the data 
dSbp1
# Out:
#                 gate  Counts
# Far Left    Far Left      39
# Left            Left       2
# Right          Right      11
# Far Right  Far Right    1179

# %%
f, ax = plt.subplots(figsize=(12,8))
ax = sns.barplot(x="gate", y="Counts", data=dSbp1, color='lemonchiffon')


ax1 = ax.axhline(0, color="darkgray", ls='--')

plt.xlabel("FACS bin", fontsize=36)
plt.ylabel("Sequencing read count", fontsize=36)
#plt.ylim(-2, 0.5)
plt.xticks(fontsize=32)
plt.yticks(fontsize=30)
sns.despine(top=True, right=True)


plt.savefig("Sbp1_countdata.png", format='png',dpi=300, bbox_inches='tight')
plt.show()

# %%
import FlowCytometryTools
from FlowCytometryTools import FCMeasurement, PolyGate, ThresholdGate

# %%
halo1 = FCMeasurement(ID='halo1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/180125_Sgn1/Halo1.fcs')
halo1.channel_names
# Out:
# ('FSC-A', 'SSC-A', 'Pacific Blue-A', 'FITC-A', 'PE-Tx-Red-YG-A', 'Time')

# %%
## load in the rest of the samples
halo2 = FCMeasurement(ID='halo2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/180125_Sgn1/Halo2.fcs')
sgn1 = FCMeasurement(ID='sgn1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/180125_Sgn1/SGN1 1.fcs')
sgn2 = FCMeasurement(ID='sgn2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/180125_Sgn1/SGN1 2.fcs')
sgn1.channel_names
# Out:
# ('FSC-A', 'SSC-A', 'Pacific Blue-A', 'FITC-A', 'PE-Tx-Red-YG-A', 'Time')

# %%
gate1= PolyGate([(50000,0),(80000,0), (80000,45000), (50000,45000)],
               ('FSC-A', 'SSC-A'), region='in')
halo1.plot(['FSC-A', 'SSC-A'], gates=gate1)
plt.show()

# %%
halo1_gated=halo1.gate(gate1)
halo1_gated.plot(['FSC-A','SSC-A'], gates=gate1)
plt.show()

# %%
gate2= PolyGate([(75000,50000),(125000,50000), (185000,125000), (150000,125000), (75000,75000)],
               ('FSC-A', 'SSC-A'), region='in')
sgn1.plot(['FSC-A', 'SSC-A'], gates=gate2)
plt.show()

# %%
## gate the rest of the samples:
halo2_gated=halo2.gate(gate1)
sgn1_gated=sgn1.gate(gate2)
sgn2_gated=sgn2.gate(gate2)
sgn2_gated.shape
# Out:
# (23620, 6)

# %%
## create FITC/TEX-R ratios to plot
halo1_gated_ratio = (halo1_gated['FITC-A']/halo1_gated['PE-Tx-Red-YG-A'])/0.86
halo1_gated_ratio = halo1_gated_ratio.apply(np.log2)
halo2_gated_ratio = (halo2_gated['FITC-A']/halo2_gated['PE-Tx-Red-YG-A'])/0.86
halo2_gated_ratio = halo2_gated_ratio.apply(np.log2)

sgn1_gated_ratio = (sgn1_gated['FITC-A']/sgn1_gated['PE-Tx-Red-YG-A'])/0.86
sgn1_gated_ratio = sgn1_gated_ratio.apply(np.log2)
sgn2_gated_ratio = (sgn2_gated['FITC-A']/sgn2_gated['PE-Tx-Red-YG-A'])/0.86
sgn2_gated_ratio = sgn2_gated_ratio.apply(np.log2)

sns.kdeplot(halo1_gated_ratio, color='silver', shade=True)
sns.kdeplot(halo2_gated_ratio, color='grey', shade=True)
sns.kdeplot(sgn1_gated_ratio, color='blue', shade=True)
sns.kdeplot(sgn2_gated_ratio, color='dodgerblue', shade=True)


plt.legend(title=None, loc='upper left', labels=['Halo control 1', 'Halo control 2', 'Sgn1 replicate 1', 'Sgn1 replicate 2'],
           fontsize=14, framealpha=0.0)
plt.ylim(0,3.0)
plt.xlim(-2,4)
plt.xlabel("Log2(YFP/RFP Ratio)", fontsize=20)
plt.ylabel("10$3$ Density", fontsize=20)
plt.yticks([0,1,2])
sns.despine()

plt.savefig("SGN1 activity plot.png", format='png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# initialise data of lists: median values of YFP / RFP per fragment 
import pandas as pd
bar = {'replicate':['rep 1', 'rep 2', 'rep 1', 'rep 2', 'rep 1', 'rep 2', 'rep 1', 'rep 2', 'rep 1', 'rep 2', 'rep 1', 'rep 2', 
                   'rep 1', 'rep 2', 'rep 1', 'rep 2', 'rep 1', 'rep 2', 'rep 1', 'rep 2', 'rep 1', 'rep 2', 'rep 1', 'rep 2'], 
           'fold change':[ -0.246, -0.259, -0.09, -0.088, -0.131, -0.111, -0.109, -0.151, -0.014, -0.025, -0.046, -0.021, 
                         0.085, 0.075, 0.021, 0.054, 0.0675, 0.0671, 0.292, 0.287, 0.407, 0.417, 0.205, 0.204], 
          'gene':['Ebs1', 'Ebs1', 'Hsp26', 'Hsp26', 'Ngr1', 'Ngr1', 'Jsn1', 'Jsn1', 'Yap1801', 'Yap1801', 'Smy2', 'Smy2', 
                 'Her1', 'Her1', 'Whi3', 'Whi3', 'Tif35', 'Tif35', 'Sro9', 'Sro9', 'Sbp1', 'Sbp1', 'Ded1', 'Ded1']} 
  
# Creates pandas DataFrame. 
dfbar = pd.DataFrame(bar) 
  
# print the data 
dfbar
# Out:
#    replicate  fold change     gene
# 0      rep 1      -0.2460     Ebs1
# 1      rep 2      -0.2590     Ebs1
# 2      rep 1      -0.0900    Hsp26
# 3      rep 2      -0.0880    Hsp26
# 4      rep 1      -0.1310     Ngr1
# 5      rep 2      -0.1110     Ngr1
# 6      rep 1      -0.1090     Jsn1
# 7      rep 2      -0.1510     Jsn1
# 8      rep 1      -0.0140  Yap1801
# 9      rep 2      -0.0250  Yap1801
# 10     rep 1      -0.0460     Smy2
# 11     rep 2      -0.0210     Smy2
# 12     rep 1       0.0850     Her1
# 13     rep 2       0.0750     Her1
# 14     rep 1       0.0210     Whi3
# 15     rep 2       0.0540     Whi3
# 16     rep 1       0.0675    Tif35
# 17     rep 2       0.0671    Tif35
# 18     rep 1       0.2920     Sro9
# 19     rep 2       0.2870     Sro9
# 20     rep 1       0.4070     Sbp1
# 21     rep 2       0.4170     Sbp1
# 22     rep 1       0.2050     Ded1
# 23     rep 2       0.2040     Ded1

# %%
#plot median values by color
sns.set_style("ticks")
ax = sns.catplot(x="gene", y="fold change", hue="replicate", data=dfbar,
                kind="bar", palette=["lightgreen","springgreen"], legend=False)

plt.xlabel("Protein fragment", fontsize=22)
plt.ylabel("Relative YFP mRNA abundance", fontsize=22)

plt.yticks([-0.3, 0, 0.301], ("1/2", "1", "2"), fontsize=18)
plt.xticks(fontsize=16)
sns.despine(top=True, right=True)
plt.axhline(0, 0,1, linestyle='-', color='lightgrey')



ax.fig.set_figwidth(12)
ax.fig.set_figheight(5)
#plt.savefig("fragment-val_barplot_green.png", format='png',dpi=300, bbox_inches='tight')
plt.show()

# %%
# Load in FL and fragment .fcs files 
halo1fl = FCMeasurement(ID='halo1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/FL proteins/FL proteins_Halo 1.fcs')
halo1fl.channel_names
# Out:
# ('FSC-A', 'SSC-A', 'Pacific Blue-A', 'FITC-A', 'PE-Tx-Red-YG-A', 'Time')

# %%
## load in the rest of FL FCS file data 
halo2fl = FCMeasurement(ID='halo2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/FL proteins/FL proteins_Halo 2.fcs')
sbp1fl = FCMeasurement(ID='sbp1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/FL proteins/FL proteins_Sbp1 1.fcs')
sbp2fl = FCMeasurement(ID='sbp2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/FL proteins/FL proteins_Sbp1 2.fcs')
sro1fl = FCMeasurement(ID='sro1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/FL proteins/FL proteins_Sro9 1.fcs')
sro2fl = FCMeasurement(ID='sro2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/FL proteins/FL proteins_Sro9 2.fcs')
yap1fl = FCMeasurement(ID='yap1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/FL proteins/FL proteins_Yap1801 1.fcs')
yap2fl = FCMeasurement(ID='yap2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/FL proteins/FL proteins_Yap1801 2.fcs')
halo2fl.channel_names
# Out:
# ('FSC-A', 'SSC-A', 'Pacific Blue-A', 'FITC-A', 'PE-Tx-Red-YG-A', 'Time')

# %%
## load in Jsn1 data 
jsn1fl1 = FCMeasurement(ID='jfl1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/Jsn1 data/Jsn1 samples redo_Full WT 1.fcs')
jsn1fl2 = FCMeasurement(ID='jfl2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/Jsn1 data/Jsn1 samples redo_Full WT 2.fcs')
jsn1halo1 = FCMeasurement(ID='jhalo1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/Jsn1 data/Jsn1 samples redo_Halo 1.fcs')
jsn1halo2 = FCMeasurement(ID='jhalo2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/Jsn1 data/Jsn1 samples redo_Halo 2.fcs')
jsn1sf = FCMeasurement(ID='jsn1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/Jsn1 data/Jsn1 samples redo_screen fragment 1.fcs')
jsn2sf = FCMeasurement(ID='jsn2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/Jsn1 data/Jsn1 samples redo_screen fragment 2.fcs')
jsn2sf.channel_names
# Out:
# ('FSC-A', 'SSC-A', 'FITC-H', 'PE-Texas Red-H', 'Pacific Blue-H', 'Time')

# %%
## load in screen fragment data 
halosf1 = FCMeasurement(ID='halo3', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/fragments/Fragments_Halo 1.fcs')
halosf2 = FCMeasurement(ID='halo4', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/fragments/Fragments_Halo 2.fcs')
sbpsf1 = FCMeasurement(ID='sbp1_1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/fragments/Fragments_Sbp 1.fcs')
sbpsf2 = FCMeasurement(ID='sbp1_2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/fragments/Fragments_Sbp 2.fcs')
sro9sf1 = FCMeasurement(ID='sro9_1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/fragments/Fragments_Sro 1.fcs')
sro9sf2 = FCMeasurement(ID='sro9_2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/fragments/Fragments_Sro 2.fcs')
yapsf1 = FCMeasurement(ID='yap1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/fragments/Fragments_Yap 1.fcs')
yapsf2 = FCMeasurement(ID='yap2', 
                        datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/fragments/Fragments_Yap 2.fcs')
yapsf2.channel_names
# Out:
# ('FSC-A', 'SSC-A', 'Pacific Blue-A', 'FITC-A', 'PE-Tx-Red-YG-A', 'Time')

# %%
halosf1.plot(['FSC-A', 'SSC-A'])
plt.show()

# %%
gate_FL= PolyGate([(55000,25000),(80000,50000), (75000,83000), (50000,70000)],('FSC-A', 'SSC-A'), region='in')
halo1fl.plot(['FSC-A', 'SSC-A'], gates=gate_FL)
plt.show()

# %%
gate_jsn= PolyGate([(12000,0),(15000,0), (15000,3000), (12000,3000)],('FSC-A', 'SSC-A'), region='in')
#jsn1_2.plot(['FSC-A', 'SSC-A'])
jsn1fl2.plot(['FSC-A', 'SSC-A'], gates=gate_jsn)
plt.xlim(0,80000)
plt.ylim(0,30000)
plt.show()

# %%
#halo1fl.plot(['FSC-A', 'SSC-A'], gates=gate_FL)
#halo2fl.plot(['FSC-A', 'SSC-A'], gates=gate_FL)
#sbp1fl.plot(['FSC-A', 'SSC-A'], gates=gate_FL)
#sbp2fl.plot(['FSC-A', 'SSC-A'], gates=gate_FL)
#sro1fl.plot(['FSC-A', 'SSC-A'], gates=gate_FL)
#sro2fl.plot(['FSC-A', 'SSC-A'], gates=gate_FL)
#yap1fl.plot(['FSC-A', 'SSC-A'], gates=gate_FL)
yap2fl.plot(['FSC-A', 'SSC-A'], gates=gate_FL)
plt.show()

# %%
#FL gated data: 
halo1fl_gated=halo1fl.gate(gate_FL)
halo2fl_gated=halo2fl.gate(gate_FL)
sbp1fl_gated=sbp1fl.gate(gate_FL)
sbp2fl_gated=sbp2fl.gate(gate_FL)
sro1fl_gated=sro1fl.gate(gate_FL)
sro2fl_gated=sro2fl.gate(gate_FL)
yap1fl_gated=yap1fl.gate(gate_FL)
yap2fl_gated=yap2fl.gate(gate_FL)
#yap2fl_gated.shape

## gate jsn1 data: 
jsn1halo1_gated=jsn1halo1.gate(gate_jsn)
jsn1halo2_gated=jsn1halo2.gate(gate_jsn)
jsn1fl1_gated=jsn1fl1.gate(gate_jsn)
jsn1fl2_gated=jsn1fl2.gate(gate_jsn)
jsn1sf_gated=jsn1sf.gate(gate_jsn)
jsn2sf_gated=jsn2sf.gate(gate_jsn)
#jsn1sf_gated.shape

## gate the rest of fragment data:
halosf1_gated=halosf1.gate(gate_FL)
halosf2_gated=halosf2.gate(gate_FL)
sbpsf1_gated=sbpsf1.gate(gate_FL)
sbpsf2_gated=sbpsf2.gate(gate_FL)
sro9sf1_gated=sro9sf1.gate(gate_FL)
sro9sf2_gated=sro9sf2.gate(gate_FL)
yapsf1_gated=yapsf1.gate(gate_FL)
yapsf2_gated=yapsf2.gate(gate_FL)

yapsf2_gated.shape
# Out:
# (21306, 6)

# %%
## compute FL ratios: 

halo1fl_gated_ratio = (halo1fl_gated['FITC-A']/halo1fl_gated['PE-Tx-Red-YG-A'])/1.14
halo1fl_gated_ratio = halo1fl_gated_ratio.apply(np.log2)
halo2fl_gated_ratio = (halo2fl_gated['FITC-A']/halo2fl_gated['PE-Tx-Red-YG-A'])/1.14
halo2fl_gated_ratio = halo2fl_gated_ratio.apply(np.log2)

sbp1fl_gated_ratio = (sbp1fl_gated['FITC-A']/sbp1fl_gated['PE-Tx-Red-YG-A'])/1.14
sbp1fl_gated_ratio = sbp1fl_gated_ratio.apply(np.log2)
sbp2fl_gated_ratio = (sbp2fl_gated['FITC-A']/sbp2fl_gated['PE-Tx-Red-YG-A'])/1.14
sbp2fl_gated_ratio = sbp2fl_gated_ratio.apply(np.log2)

sro1fl_gated_ratio = (sro1fl_gated['FITC-A']/sro1fl_gated['PE-Tx-Red-YG-A'])/1.14
sro1fl_gated_ratio = sro1fl_gated_ratio.apply(np.log2)
sro2fl_gated_ratio = (sro2fl_gated['FITC-A']/sro2fl_gated['PE-Tx-Red-YG-A'])/1.14
sro2fl_gated_ratio = sro2fl_gated_ratio.apply(np.log2)

yap1fl_gated_ratio = (yap1fl_gated['FITC-A']/yap1fl_gated['PE-Tx-Red-YG-A'])/1.14
yap1fl_gated_ratio = yap1fl_gated_ratio.apply(np.log2)
yap2fl_gated_ratio = (yap2fl_gated['FITC-A']/yap2fl_gated['PE-Tx-Red-YG-A'])/1.14
yap2fl_gated_ratio = yap2fl_gated_ratio.apply(np.log2)

# %%
## compute Jsn1 ratios 
jsn1halo1_gated_ratio = (jsn1halo1_gated['FITC-H']/jsn1halo1_gated['PE-Texas Red-H'])/1.265
jsn1halo1_gated_ratio = jsn1halo1_gated_ratio.apply(np.log2)
jsn1halo2_gated_ratio = (jsn1halo2_gated['FITC-H']/jsn1halo2_gated['PE-Texas Red-H'])/1.265
jsn1halo2_gated_ratio = jsn1halo2_gated_ratio.apply(np.log2)

jsn1sf_gated_ratio = (jsn1sf_gated['FITC-H']/jsn1sf_gated['PE-Texas Red-H'])/1.265
jsn1sf_gated_ratio = jsn1sf_gated_ratio.apply(np.log2)
jsn2sf_gated_ratio = (jsn2sf_gated['FITC-H']/jsn2sf_gated['PE-Texas Red-H'])/1.265
jsn2sf_gated_ratio = jsn2sf_gated_ratio.apply(np.log2)

jsn1fl1_gated_ratio = (jsn1fl1_gated['FITC-H']/jsn1fl1_gated['PE-Texas Red-H'])/1.265
jsn1fl1_gated_ratio = jsn1fl1_gated_ratio.apply(np.log2)
jsn1fl2_gated_ratio = (jsn1fl2_gated['FITC-H']/jsn1fl2_gated['PE-Texas Red-H'])/1.265
jsn1fl2_gated_ratio = jsn1fl2_gated_ratio.apply(np.log2)

# %%
halosf1_gated_ratio = (halosf1_gated['FITC-A']/halosf1_gated['PE-Tx-Red-YG-A'])/1.1
halosf1_gated_ratio = halosf1_gated_ratio.apply(np.log2)
halosf2_gated_ratio = (halosf2_gated['FITC-A']/halosf2_gated['PE-Tx-Red-YG-A'])/1.1
halosf2_gated_ratio = halosf2_gated_ratio.apply(np.log2)

sbpsf1_gated_ratio = (sbpsf1_gated['FITC-A']/sbpsf1_gated['PE-Tx-Red-YG-A'])/1.1
sbpsf1_gated_ratio = sbpsf1_gated_ratio.apply(np.log2)
sbpsf2_gated_ratio = (sbpsf2_gated['FITC-A']/sbpsf2_gated['PE-Tx-Red-YG-A'])/1.1
sbpsf2_gated_ratio = sbpsf2_gated_ratio.apply(np.log2)

sro9sf1_gated_ratio = (sro9sf1_gated['FITC-A']/sro9sf1_gated['PE-Tx-Red-YG-A'])/1.1
sro9sf1_gated_ratio = sro9sf1_gated_ratio.apply(np.log2)
sro9sf2_gated_ratio = (sro9sf2_gated['FITC-A']/sro9sf2_gated['PE-Tx-Red-YG-A'])/1.1
sro9sf2_gated_ratio = sro9sf2_gated_ratio.apply(np.log2)

yapsf1_gated_ratio = (yapsf1_gated['FITC-A']/yapsf1_gated['PE-Tx-Red-YG-A'])/1.1
yapsf1_gated_ratio = yapsf1_gated_ratio.apply(np.log2)
yapsf2_gated_ratio = (yapsf2_gated['FITC-A']/yapsf2_gated['PE-Tx-Red-YG-A'])/1.1
yapsf2_gated_ratio = yapsf2_gated_ratio.apply(np.log2)

# %%
#sns.kdeplot(halosf1_gated_ratio, color='silver', shade=True)
#sns.kdeplot(sbp2fl_gated_ratio, color='darkviolet', shade=True)
#sns.kdeplot(sbpsf1_gated_ratio, color='violet', shade=True)

sns.kdeplot(halosf2_gated_ratio, color='silver', shade=True)
sns.kdeplot(sbp1fl_gated_ratio, color='darkviolet', shade=True)
sns.kdeplot(sbpsf2_gated_ratio, color='lightpink', shade=True)

plt.legend(title=None, labels=['Control', 'Sbp1', 'Sbp1(14-178)'],
            bbox_to_anchor=(1.05, 1), loc=2, fontsize=14, framealpha=0.0)

plt.xlim(-3,3)
plt.xticks([-2, -1, 0, 1, 2, 3], ("1/4", "1/2", "1", "2", "4", "8"), fontsize=14)
plt.ylim(0,1.58)
plt.yticks([1], (""))
sns.despine(top=True, right=True)

plt.axvline(1.14, 0,1, linestyle='--', color='darkviolet')
plt.axvline(1.55, 0,1, linestyle='--', color='lightpink')


#plt.savefig("Sbp1FL.png", format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#sns.kdeplot(halosf2_gated_ratio, color='lightgrey', shade=True, legend=True)
#sns.kdeplot(yapsf2_gated_ratio, color='cyan', shade=True, legend=True)
#sns.kdeplot(yap2fl_gated_ratio, color='b', shade=True, legend=True)

sns.kdeplot(halosf1_gated_ratio, color='silver', shade=True, legend=True)
sns.kdeplot(yap1fl_gated_ratio, color='b', shade=True, legend=True)
sns.kdeplot(yapsf1_gated_ratio, color='cyan', shade=True, legend=True)

plt.legend(title=None, labels=['Control', 'Yap1801', 'Yap1801(374-527)'],
            bbox_to_anchor=(1.05, 1), loc=2, fontsize=14, framealpha=0.0)

plt.xlim(-3,3)
plt.xticks([-2, -1, 0, 1, 2, 3], ("1/4", "1/2", "1", "2", "4", "8"), fontsize=14)

plt.axvline(-0.62, 0,1, linestyle='--', color='c')
plt.axvline(-0.23, 0,1, linestyle='--', color='b')

plt.yticks([1], (""))
sns.despine(top=True, right=True)
#plt.savefig("Yap1801FL.png", format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#sns.kdeplot(jsn1halo2_gated_ratio, color='lightgrey', shade=True, legend=True)
#sns.kdeplot(jsn1sf_gated_ratio, color='lawngreen', shade=True, legend=True)
#sns.kdeplot(jsn1fl2_gated_ratio, color='g', shade=True, legend=True)

sns.kdeplot(jsn1halo1_gated_ratio, color='lightgrey', shade=True, legend=True)
sns.kdeplot(jsn1fl1_gated_ratio, color='g', shade=True, legend=True)
sns.kdeplot(jsn2sf_gated_ratio, color='lawngreen', shade=True, legend=True)



plt.legend(title=None, labels=['Control', 'Jsn1', 'Jsn1(144-295)'],
            bbox_to_anchor=(1.05, 1), loc=2, fontsize=14, framealpha=0.0)

plt.xlim(-3,3)
plt.ylim(0, 1.5)
plt.xticks([-2, -1, 0, 1, 2, 3], ("1/4", "1/2", "1", "2", "4", "8"), fontsize=14)
plt.yticks([1], (""))
sns.despine(top=True, right=True)

plt.axvline(-0.62, 0,1, linestyle='--', color='g')
plt.axvline(-0.46, 0,1, linestyle='--', color='limegreen')

#plt.savefig("Jsn1FL.png", format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#sns.kdeplot(halosf2_gated_ratio, color='lightgrey', shade=True, legend=True)
#sns.kdeplot(sro9sf2_gated_ratio, color='khaki', shade=True, legend=True)
#sns.kdeplot(sro1fl_gated_ratio, color='darkorange', shade=True, legend=True)

sns.kdeplot(halosf1_gated_ratio, color='silver', shade=True, legend=True)
sns.kdeplot(sro2fl_gated_ratio, color='orange', shade=True, legend=True)
sns.kdeplot(sro9sf1_gated_ratio, color='gold', shade=True, legend=True)

plt.legend(title=None, labels=['Control', 'Sro9', 'Sro9(14-151)'],
           bbox_to_anchor=(1.05, 1), loc=2, fontsize=14, framealpha=0.0)

plt.xlim(-3,3)
plt.ylim(0,1.65)
plt.xticks([-2, -1, 0, 1, 2, 3], ("1/4", "1/2", "1", "2", "4", "8"), fontsize=14)
plt.yticks([1], (""))
sns.despine(top=True, right=True)

plt.axvline(1, 0,1, linestyle='--', color='orange')
plt.axvline(2, 0,1, linestyle='--', color='darkorange')

#plt.savefig("Sro9FL.png", format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
## Load first sample and check what channels are named 
H1_0 = FCMeasurement(ID='H1_0', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_Halo 1 0H.fcs')

H1_0.channel_names
# Out:
# ('FSC-A', 'SSC-A', 'FITC-H', 'PE-Texas Red-H', 'Pacific Blue-H', 'Time')

# %%
## load the rest of samples 
H2_0 = FCMeasurement(ID='H2_0', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_Halo 2 0H.fcs')
H1_1 = FCMeasurement(ID='H1_1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_Halo1 1H.fcs')
H2_1 = FCMeasurement(ID='H2_1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_Halo2 1H.fcs')
H1_2 = FCMeasurement(ID='H1_2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_Halo1 2H.fcs')
H2_2 = FCMeasurement(ID='H2_2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_Halo2 2H.fcs')
H1_4 = FCMeasurement(ID='H1_4', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_Halo1 4H.fcs')
H2_4 = FCMeasurement(ID='H2_4', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_Halo2 4H.fcs')

FL1_0 = FCMeasurement(ID='FL1_0', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_yFL1 0H.fcs')
FL2_0 = FCMeasurement(ID='FL2_0', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_yFL2 0H.fcs')
FL1_1 = FCMeasurement(ID='FL1_1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_yFL1 1H.fcs')
FL2_1 = FCMeasurement(ID='FL2_1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_yFL2 1H.fcs')
FL1_2 = FCMeasurement(ID='FL1_2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_yFL1 2H.fcs')
FL2_2 = FCMeasurement(ID='FL2_2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_yFL2 2H.fcs')
FL1_4 = FCMeasurement(ID='FL1_4', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_yFL1 4H.fcs')
FL2_4 = FCMeasurement(ID='FL2_4', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_yFL2 4H.fcs')

ynf1_0 = FCMeasurement(ID='FL1_2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_ynofrag 0H.fcs')
ynf2_0 = FCMeasurement(ID='FL2_2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_ynofrag 2 0H.fcs')
ynf1_1 = FCMeasurement(ID='FL1_2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_ynofrag1 1H.fcs')
ynf2_1 = FCMeasurement(ID='FL1_2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_ynofrag2 1H.fcs')
ynf1_2 = FCMeasurement(ID='FL1_2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_ynofrag1 2H.fcs')
ynf2_2 = FCMeasurement(ID='FL1_2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_ynofrag2 2H.fcs')
ynf1_4 = FCMeasurement(ID='FL1_2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_ynofrag1 4H.fcs')
ynf2_4 = FCMeasurement(ID='FL1_2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20191203 KS/YEL inducible_ynofrag2 4H.fcs')

# %%
#plot FSC vs SSC data one at a time: (try with both replicates)

#H2_0.plot(['FSC-A', 'SSC-A'])
#H2_1.plot(['FSC-A', 'SSC-A'])
#H2_2.plot(['FSC-A', 'SSC-A'])
H2_4.plot(['FSC-A', 'SSC-A'])

plt.show()

# %%
#draw gate to exclude unhealthy cells 
## check each population with the gate individually 

gate1= PolyGate([(10000,0),(25000,0), (25000,25000), (10000,25000)],
               ('FSC-A', 'SSC-A'), region='in')

#H2_0.plot(['FSC-A', 'SSC-A'], gates=gate1)
H2_1.plot(['FSC-A', 'SSC-A'], gates=gate1)


plt.show()

# %%
H2_0gated=H2_0.gate(gate1)
H2_0gated.plot(['FSC-A','SSC-A'], gates=gate1)
plt.show()

# %%
## gate populations around healthy cells in the middle

H1_0gated=H1_0.gate(gate1)
H2_0gated=H2_0.gate(gate1)
H1_1gated=H1_1.gate(gate1)
H2_1gated=H2_1.gate(gate1)
H1_2gated=H1_2.gate(gate1)
H2_2gated=H2_2.gate(gate1)
H1_4gated=H1_4.gate(gate1)
H2_4gated=H2_4.gate(gate1)

FL1_0gated=FL1_0.gate(gate1)
FL2_0gated=FL2_0.gate(gate1)
FL1_1gated=FL1_1.gate(gate1)
FL2_1gated=FL2_1.gate(gate1)
FL1_2gated=FL1_2.gate(gate1)
FL2_2gated=FL2_2.gate(gate1)
FL1_4gated=FL1_4.gate(gate1)
FL2_4gated=FL2_4.gate(gate1)

ynf1_0gated=ynf1_0.gate(gate1)
ynf2_0gated=ynf2_0.gate(gate1)
ynf1_1gated=ynf1_1.gate(gate1)
ynf2_1gated=ynf2_1.gate(gate1)
ynf1_2gated=ynf1_2.gate(gate1)
ynf2_2gated=ynf2_2.gate(gate1)
ynf1_4gated=ynf1_4.gate(gate1)
ynf2_4gated=ynf2_4.gate(gate1)

# %%
## calculate ratios of YFP/RFP relative to Halo

H1_0_ratio = (H1_0gated['FITC-H']/H1_0gated['PE-Texas Red-H'])
H1_0_ratio = H1_0_ratio.apply(np.log2)
H2_0_ratio = (H2_0gated['FITC-H']/H2_0gated['PE-Texas Red-H'])
H2_0_ratio = H2_0_ratio.apply(np.log2)

H1_1_ratio = (H1_1gated['FITC-H']/H1_1gated['PE-Texas Red-H'])/1.11
H1_1_ratio = H1_1_ratio.apply(np.log2)
H2_1_ratio = (H2_1gated['FITC-H']/H2_1gated['PE-Texas Red-H'])/1.11
H2_1_ratio = H2_1_ratio.apply(np.log2)

H1_2_ratio = (H1_2gated['FITC-H']/H1_2gated['PE-Texas Red-H'])/0.9
H1_2_ratio = H1_2_ratio.apply(np.log2)
H2_2_ratio = (H2_2gated['FITC-H']/H2_2gated['PE-Texas Red-H'])/0.9
H2_2_ratio = H2_2_ratio.apply(np.log2)

H1_4_ratio = (H1_4gated['FITC-H']/H1_4gated['PE-Texas Red-H'])/1.08
H1_4_ratio = H1_4_ratio.apply(np.log2)
H2_4_ratio = (H2_4gated['FITC-H']/H2_4gated['PE-Texas Red-H'])/1.08
H2_4_ratio = H2_4_ratio.apply(np.log2)

####
FL1_0_ratio = (FL1_0gated['FITC-H']/FL1_0gated['PE-Texas Red-H'])/1.0
FL1_0_ratio = FL1_0_ratio.apply(np.log2)
FL2_0_ratio = (FL2_0gated['FITC-H']/FL2_0gated['PE-Texas Red-H'])/1.0
FL2_0_ratio = FL2_0_ratio.apply(np.log2)

FL1_1_ratio = (FL1_1gated['FITC-H']/FL1_1gated['PE-Texas Red-H'])/1.11
FL1_1_ratio = FL1_1_ratio.apply(np.log2)
FL2_1_ratio = (FL2_1gated['FITC-H']/FL2_1gated['PE-Texas Red-H'])/1.11
FL2_1_ratio = FL2_1_ratio.apply(np.log2)

FL1_2_ratio = (FL1_2gated['FITC-H']/FL1_2gated['PE-Texas Red-H'])/0.9
FL1_2_ratio = FL1_2_ratio.apply(np.log2)
FL2_2_ratio = (FL2_2gated['FITC-H']/FL2_2gated['PE-Texas Red-H'])/0.9
FL2_2_ratio = FL2_2_ratio.apply(np.log2)

FL1_4_ratio = (FL1_4gated['FITC-H']/FL1_4gated['PE-Texas Red-H'])/1.08
FL1_4_ratio = FL1_4_ratio.apply(np.log2)
FL2_4_ratio = (FL2_4gated['FITC-H']/FL2_4gated['PE-Texas Red-H'])/1.08
FL2_4_ratio = FL2_4_ratio.apply(np.log2)

###
ynf1_0_ratio = (ynf1_0gated['FITC-H']/ynf1_0gated['PE-Texas Red-H'])/1.0
ynf1_0_ratio = ynf1_0_ratio.apply(np.log2)
ynf2_0_ratio = (ynf2_0gated['FITC-H']/ynf2_0gated['PE-Texas Red-H'])/1.0
ynf2_0_ratio = ynf2_0_ratio.apply(np.log2)

ynf1_1_ratio = (ynf1_1gated['FITC-H']/ynf1_1gated['PE-Texas Red-H'])/1.11
ynf1_1_ratio = ynf1_1_ratio.apply(np.log2)
ynf2_1_ratio = (ynf2_1gated['FITC-H']/ynf2_1gated['PE-Texas Red-H'])/1.11
ynf2_1_ratio = ynf2_1_ratio.apply(np.log2)

ynf1_2_ratio = (ynf1_2gated['FITC-H']/ynf1_2gated['PE-Texas Red-H'])/0.9
ynf1_2_ratio = ynf1_2_ratio.apply(np.log2)
ynf2_2_ratio = (ynf2_2gated['FITC-H']/ynf2_2gated['PE-Texas Red-H'])/0.9
ynf2_2_ratio = ynf2_2_ratio.apply(np.log2)

ynf1_4_ratio = (ynf1_4gated['FITC-H']/ynf1_4gated['PE-Texas Red-H'])/1.08
ynf1_4_ratio = ynf1_4_ratio.apply(np.log2)
ynf2_4_ratio = (ynf2_4gated['FITC-H']/ynf2_4gated['PE-Texas Red-H'])/1.08
ynf2_4_ratio = ynf2_4_ratio.apply(np.log2)

# %%
sns.kdeplot(H1_0_ratio, color='silver', shade=True)
sns.kdeplot(H2_0_ratio, color='lightgrey', shade=True)
sns.kdeplot(FL1_0_ratio, color='deepskyblue', shade=True)
sns.kdeplot(FL2_0_ratio, color='dodgerblue', shade=True)
sns.kdeplot(ynf1_0_ratio, color='gold', shade=True)
sns.kdeplot(ynf2_0_ratio, color='orange', shade=True)

plt.xlim(-1,1)

plt.yticks([1], "")
plt.xticks([-3, -2, -1, 0, 1], ("1/8", "1/4", "1/2", "1",  "2"), fontsize=16)
plt.xlabel("Normalized YFP expression", fontsize=20)
plt.ylabel("Density", fontsize=20)
sns.despine()

plt.legend(title=None, loc='upper left', labels=['Halo1', 'Halo2',
                                                    'Gta1 FL1', 'Gta1 FL2',
                                                    'Gta1 nofrag1', 'Gta1 nofrag2'], fontsize=14)

#plt.savefig("Gta1-induction_uninduced.png", format='png',dpi=300, bbox_inches='tight')
plt.show()

# %%
sns.kdeplot(H1_1_ratio, color='silver', shade=True)
sns.kdeplot(H2_1_ratio, color='lightgrey', shade=True)
sns.kdeplot(FL1_1_ratio, color='deepskyblue', shade=True)
sns.kdeplot(FL2_1_ratio, color='dodgerblue', shade=True)
sns.kdeplot(ynf1_1_ratio, color='gold', shade=True)
sns.kdeplot(ynf2_1_ratio, color='orange', shade=True)

plt.xlim(-1,1)

plt.yticks([1], "")
plt.xticks([-3, -2, -1, 0, 1], ("1/8", "1/4", "1/2", "1",  "2"), fontsize=16)
plt.xlabel("Normalized YFP expression", fontsize=20)
plt.ylabel("Density", fontsize=20)
sns.despine()

plt.legend(title=None, loc='upper left', labels=['Halo1', 'Halo2',
                                                    'Gta1 FL1', 'Gta1 FL2',
                                                    'Gta1 nofrag1', 'Gta1 nofrag2'], fontsize=14)

#plt.savefig("Gta1-induction_1HR.png", format='png',dpi=300, bbox_inches='tight')
plt.show()

# %%
sns.kdeplot(H1_2_ratio, color='silver', shade=True)
sns.kdeplot(H2_2_ratio, color='lightgrey', shade=True)
sns.kdeplot(FL1_2_ratio, color='mediumorchid', shade=True)
sns.kdeplot(FL2_2_ratio, color='darkviolet', shade=True)
sns.kdeplot(ynf1_2_ratio, color='mediumseagreen', shade=True)
sns.kdeplot(ynf2_2_ratio, color='lightseagreen', shade=True)

plt.xlim(-1,1)

plt.yticks([1], " ")
plt.xticks([-3, -2, -1, -0.5, 0, 0.5, 1], ("0.125", "0.25", "0.5", "0.7", "1", "1.4", "2"), fontsize=16)
sns.despine()

plt.legend(title='2HR induction', loc='upper left', labels=['Halo1', 'Halo2',
                                                    'Gta1 FL1', 'Gta1 FL2',
                                                    'Gta1 nofrag1', 'Gta1 nofrag2'])

plt.show()

# %%
sns.kdeplot(H1_4_ratio, color='silver', shade=True)
sns.kdeplot(H2_4_ratio, color='lightgrey', shade=True)
sns.kdeplot(FL1_4_ratio, color='mediumorchid', shade=True)
sns.kdeplot(FL2_4_ratio, color='darkviolet', shade=True)
sns.kdeplot(ynf1_4_ratio, color='mediumseagreen', shade=True)
sns.kdeplot(ynf2_4_ratio, color='lightseagreen', shade=True)

plt.xlim(-1,1)

plt.yticks([1], " ")
plt.xticks([-3, -2, -1, -0.5, 0, 0.5, 1], ("0.125", "0.25", "0.5", "0.7", "1", "1.4", "2"), fontsize=16)
sns.despine()

plt.legend(title='4HR induction', loc='upper left', labels=['Halo1', 'Halo2',
                                                    'Gta1 FL1', 'Gta1 FL2',
                                                    'Gta1 nofrag1', 'Gta1 nofrag2'])

plt.show()

# %%
## checking tether fusion expression / stability via BFP fluorescence 

sns.kdeplot(np.log10(FL1_0gated['Pacific Blue-H']), color='lightpink')
sns.kdeplot(np.log10(FL2_0gated['Pacific Blue-H']), color='lavenderblush')

sns.kdeplot(np.log10(FL1_2gated['Pacific Blue-H']), color='mediumorchid')
sns.kdeplot(np.log10(FL2_2gated['Pacific Blue-H']), color='darkviolet')

sns.kdeplot(np.log10(FL1_4gated['Pacific Blue-H']), color='deeppink')
sns.kdeplot(np.log10(FL2_4gated['Pacific Blue-H']), color='crimson')

plt.axvline(3.0, 0,4.5, linestyle='--', color='lightgray')
plt.xlim(1.5,4)

plt.legend(title='FL Gta1 expression', loc='upper left', labels=['0H FL1', '0H FL2', '2H FL1', '2H FL2', '4H FL1', '4H FL2'])

plt.yticks([1], " ")
plt.xticks([2,2.5,3,3.5,4], ("2", "2.5", "3", "3.5", "4"), fontsize=16)
sns.despine()

#plt.savefig("Gta1_BFP-FLonly.png", format='png',dpi=300, bbox_inches='tight')
plt.show()

# %%
## checking tether fusion expression / stability via BFP fluorescence 


sns.kdeplot(np.log10(ynf1_0gated['Pacific Blue-H']), color='palegreen')
sns.kdeplot(np.log10(ynf2_0gated['Pacific Blue-H']), color='lightgreen')

sns.kdeplot(np.log10(ynf1_2gated['Pacific Blue-H']), color='darkturquoise')
sns.kdeplot(np.log10(ynf2_2gated['Pacific Blue-H']), color='cadetblue')

sns.kdeplot(np.log10(ynf1_4gated['Pacific Blue-H']), color='mediumblue')
sns.kdeplot(np.log10(ynf2_4gated['Pacific Blue-H']), color='royalblue')

plt.axvline(3.0, 0,4.5, linestyle='--', color='lightgray')
plt.xlim(1.5,4)

plt.legend(title='Gta1 nofrag expression', loc='upper left', labels=['0H nofrag1', '0H nofrag2', '2H nofrag1', '2H nofrag2', 
                                                     '4H nofrag1', '4H nofrag2'])

plt.yticks([1], " ")
plt.xticks([2,2.5,3,3.5,4], ("2", "2.5", "3", "3.5", "4"), fontsize=16)
sns.despine()

#plt.savefig("Gta1_BFP-ynf_only.png", format='png',dpi=300, bbox_inches='tight')
plt.show()

# %%
halo1 = FCMeasurement(ID='halo1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/191023_sgn1FC/YEL and Sro9 test_Halo SRO 1.fcs')
halo1.channel_names
# Out:
# ('FSC-A', 'SSC-A', 'Pacific Blue-A', 'FITC-A', 'PE-Tx-Red-YG-A', 'Time')

# %%
halo2 = FCMeasurement(ID='halo2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/191023_sgn1FC/YEL and Sro9 test_Halo SRO 2.fcs')
act1 = FCMeasurement(ID='act1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/191023_sgn1FC/YEL and Sro9 test_Sro Act 1.fcs')
act2 = FCMeasurement(ID='act2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/191023_sgn1FC/YEL and Sro9 test_Sro Act 2.fcs')
FL1 = FCMeasurement(ID='FL1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/191023_sgn1FC/YEL and Sro9 test_Sro FL 1.fcs')
FL2 = FCMeasurement(ID='FL2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/191023_sgn1FC/YEL and Sro9 test_Sro FL 2.fcs')
nhq1 = FCMeasurement(ID='nhq1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/191023_sgn1FC/YEL and Sro9 test_Sro NHQ 1.fcs')
nhq2 = FCMeasurement(ID='nhq2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/191023_sgn1FC/YEL and Sro9 test_Sro NHQ 2.fcs')

# %%
halo3 = FCMeasurement(ID='halo3', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/191023_sgn1FC/HALO1.fcs')
halo4 = FCMeasurement(ID='halo4', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/191023_sgn1FC/HALO2.fcs')
rrm1 = FCMeasurement(ID='rrm1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/191023_sgn1FC/SRO1.fcs')
rrm2 = FCMeasurement(ID='rrm2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/191023_sgn1FC/SRO2.fcs')

# %%
#halo1.plot(['FSC-A', 'SSC-A'])
#act1.plot(['FSC-A','SSC-A'])
#FL2.plot(['FSC-A','SSC-A'])
#nhq2.plot(['FSC-A','SSC-A'])
halo3.plot(['FSC-A', 'SSC-A'])
plt.show()

# %%
gate1= PolyGate([(50000,30000),(80000,60000), (65000,80000), (55000,70000)],
               ('FSC-A', 'SSC-A'), region='in')
#halo1.plot(['FSC-A', 'SSC-A'], gates=gate1)
rrm1.plot(['FSC-A', 'SSC-A'], gates=gate1)
plt.show()

# %%
halo1_gated=halo1.gate(gate1)
halo1_gated.plot(['FSC-A','SSC-A'], gates=gate1)
plt.show()

# %%
act1_gated=act1.gate(gate1)
act1_gated.plot(['FSC-A','SSC-A'], gates=gate1)
plt.show()

# %%
halo1_gated=halo1.gate(gate1)
halo2_gated=halo2.gate(gate1)
halo3_gated=halo3.gate(gate1)
halo4_gated=halo4.gate(gate1)
act2_gated=act2.gate(gate1)
act1_gated=act1.gate(gate1)
nhq1_gated=nhq1.gate(gate1)
nhq2_gated=nhq2.gate(gate1)
FL1_gated=FL1.gate(gate1)
FL2_gated=FL2.gate(gate1)
halo3_gated=halo3.gate(gate1)
halo4_gated=halo4.gate(gate1)
rrm1_gated=rrm1.gate(gate1)
rrm2_gated=rrm2.gate(gate1)

# %%
halo1_gated_ratio = (halo1_gated['FITC-A']/halo1_gated['PE-Tx-Red-YG-A'])/1.26
halo1_gated_ratio = halo1_gated_ratio.apply(np.log2)
halo2_gated_ratio = (halo2_gated['FITC-A']/halo2_gated['PE-Tx-Red-YG-A'])/1.26
halo2_gated_ratio = halo2_gated_ratio.apply(np.log2)

halo3_gated_ratio = (halo3_gated['FITC-A']/halo3_gated['PE-Tx-Red-YG-A'])/0.95
halo3_gated_ratio = halo3_gated_ratio.apply(np.log2)
halo4_gated_ratio = (halo4_gated['FITC-A']/halo4_gated['PE-Tx-Red-YG-A'])/0.95
halo4_gated_ratio = halo4_gated_ratio.apply(np.log2)

act1_gated_ratio = (act1_gated['FITC-A']/act1_gated['PE-Tx-Red-YG-A'])/1.26
act1_gated_ratio = act1_gated_ratio.apply(np.log2)
act2_gated_ratio = (act2_gated['FITC-A']/act2_gated['PE-Tx-Red-YG-A'])/1.26
act2_gated_ratio = act2_gated_ratio.apply(np.log2)

nhq1_gated_ratio = (nhq1_gated['FITC-A']/nhq1_gated['PE-Tx-Red-YG-A'])/1.26
nhq1_gated_ratio = nhq1_gated_ratio.apply(np.log2)
nhq2_gated_ratio = (nhq2_gated['FITC-A']/nhq2_gated['PE-Tx-Red-YG-A'])/1.26
nhq2_gated_ratio = nhq2_gated_ratio.apply(np.log2)

FL1_gated_ratio = (FL2_gated['FITC-A']/FL2_gated['PE-Tx-Red-YG-A'])/1.26
FL1_gated_ratio = FL1_gated_ratio.apply(np.log2)
FL2_gated_ratio = (FL2_gated['FITC-A']/FL2_gated['PE-Tx-Red-YG-A'])/1.26
FL2_gated_ratio = FL2_gated_ratio.apply(np.log2)

rrm1_gated_ratio = (rrm1_gated['FITC-A']/rrm1_gated['PE-Tx-Red-YG-A'])/0.95
rrm1_gated_ratio = rrm1_gated_ratio.apply(np.log2)
rrm2_gated_ratio = (rrm2_gated['FITC-A']/rrm2_gated['PE-Tx-Red-YG-A'])/0.95
rrm2_gated_ratio = rrm2_gated_ratio.apply(np.log2)

# %%
sns.kdeplot(halo1_gated_ratio, color='lightgrey', shade=True)
sns.kdeplot(halo2_gated_ratio, color='silver', shade=True)
sns.kdeplot(act1_gated_ratio, color='peachpuff', shade=True)
sns.kdeplot(act2_gated_ratio, color='navajowhite', shade=True)
sns.kdeplot(nhq1_gated_ratio, color='palegreen', shade=True)
sns.kdeplot(nhq2_gated_ratio, color='lightgreen', shade=True)
sns.kdeplot(FL1_gated_ratio, color='pink', shade=True)
sns.kdeplot(FL2_gated_ratio, color='hotpink', shade=True)
#sns.kdeplot(rrm2_gated_ratio, color='dodgerblue', shade=True)
#sns.kdeplot(rrm1_gated_ratio, color='peachpuff', shade=True)


plt.ylim(0,2.1)
plt.xlim(-1,4)
plt.xlabel(" ")
plt.ylabel(" ")
plt.yticks([1], (""))
plt.xticks([-1,0,1,2,3], ("1/2", "1", "2", "4", "8"), fontsize=18)
sns.despine()

#plt.savefig("220309_Sro9-FLvfrag.png", format='png',dpi=300, bbox_inches='tight')
plt.show()

# %%
sns.kdeplot(halo3_gated_ratio, color='lightgray', shade=True)
sns.kdeplot(halo4_gated_ratio, color='silver', shade=True)

sns.kdeplot(rrm2_gated_ratio, color='dodgerblue', shade=True)
sns.kdeplot(rrm1_gated_ratio, color='skyblue', shade=True)

plt.ylim(0,2.1)
plt.xlim(-1.5,1.5)
plt.xlabel(" ")
plt.ylabel(" ")
plt.yticks([1], (""))
plt.xticks([-1,0,1], ("1/2", "1", "2"), fontsize=18)
sns.despine()

#plt.savefig("220309_Sro9-rrmonly.png", format='png',dpi=300, bbox_inches='tight')
plt.show()

# %%
halo1fl = FCMeasurement(ID='halo1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20190917 FL test/FL proteins_Halo 1.fcs')
halo2fl = FCMeasurement(ID='halo2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20190917 FL test/FL proteins_Halo 2.fcs')
cdc1fl = FCMeasurement(ID='Cdc1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20190917 FL test/FL proteins_Cdc48 1.fcs')
cdc2fl = FCMeasurement(ID='Cdc2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20190917 FL test/FL proteins_Cdc48 2.fcs')

halo2fl.channel_names
# Out:
# ('FSC-A', 'SSC-A', 'Pacific Blue-A', 'FITC-A', 'PE-Tx-Red-YG-A', 'Time')

# %%
halo1fl.plot(['FSC-A', 'SSC-A'])
plt.show()

# %%
gate_FL= PolyGate([(55000,25000),(80000,50000), (75000,83000), (50000,70000)],('FSC-A', 'SSC-A'), region='in')
halo1fl.plot(['FSC-A', 'SSC-A'], gates=gate_FL)
plt.show()

# %%
#FL gated data: 
halo1fl_gated=halo1fl.gate(gate_FL)
halo2fl_gated=halo2fl.gate(gate_FL)
cdc1fl_gated=cdc1fl.gate(gate_FL)
cdc2fl_gated=cdc2fl.gate(gate_FL)



cdc2fl_gated.shape
# Out:
# (14707, 6)

# %%
## compute FL ratios: 

halo1fl_gated_ratio = (halo1fl_gated['FITC-A']/halo1fl_gated['PE-Tx-Red-YG-A'])/1.09
halo1fl_gated_ratio = halo1fl_gated_ratio.apply(np.log2)
halo2fl_gated_ratio = (halo2fl_gated['FITC-A']/halo2fl_gated['PE-Tx-Red-YG-A'])/1.09
halo2fl_gated_ratio = halo2fl_gated_ratio.apply(np.log2)

cdc1fl_gated_ratio = (cdc1fl_gated['FITC-A']/cdc1fl_gated['PE-Tx-Red-YG-A'])/1.09
cdc1fl_gated_ratio = cdc1fl_gated_ratio.apply(np.log2)
cdc2fl_gated_ratio = (cdc2fl_gated['FITC-A']/cdc2fl_gated['PE-Tx-Red-YG-A'])/1.09
cdc2fl_gated_ratio = cdc2fl_gated_ratio.apply(np.log2)

# %%
halo1 = FCMeasurement(ID='halo1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20190730 fragment test III/Fragments_Halo 1.fcs')
halo2 = FCMeasurement(ID='halo2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20190730 fragment test III/Fragments_Halo 2.fcs')

cdc1 = FCMeasurement(ID='cdc1', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20190730 fragment test III/Fragments_Cdc 1.fcs')
cdc2 = FCMeasurement(ID='cdc2', 
                       datafile= '/Users/kendrareynaud/Documents/Ingolia lab files/flow_cytometry/20190730 fragment test III/Fragments_Cdc 2.fcs')
halo1.channel_names
# Out:
# ('FSC-A', 'SSC-A', 'Pacific Blue-A', 'FITC-A', 'PE-Tx-Red-YG-A', 'Time')

# %%
halo1.plot(['FSC-A', 'SSC-A'])
plt.show()

# %%
gate1= PolyGate([(35000,15000),(80000,15000), (80000,100000), (50000,100000)],('FSC-A', 'SSC-A'), region='in')
halo1.plot(['FSC-A', 'SSC-A'], gates=gate1)
plt.show()

# %%
halo1_gated=halo1.gate(gate1)
halo2_gated=halo2.gate(gate1)
cdc1_gated=cdc1.gate(gate1)
cdc2_gated=cdc2.gate(gate1)

# %%
halo1_gated_ratio = (halo1_gated['FITC-A']/halo1_gated['PE-Tx-Red-YG-A'])/1.05
halo1_gated_ratio = halo1_gated_ratio.apply(np.log2)

halo2_gated_ratio = (halo2_gated['FITC-A']/halo2_gated['PE-Tx-Red-YG-A'])/1.05
halo2_gated_ratio = halo2_gated_ratio.apply(np.log2)

cdc1_gated_ratio = (cdc1_gated['FITC-A']/cdc1_gated['PE-Tx-Red-YG-A'])/1.05
cdc1_gated_ratio = cdc1_gated_ratio.apply(np.log2)

cdc2_gated_ratio = (cdc2_gated['FITC-A']/cdc2_gated['PE-Tx-Red-YG-A'])/1.05
cdc2_gated_ratio = cdc2_gated_ratio.apply(np.log2)

# %%
sns.kdeplot(halo1_gated_ratio, color='silver', shade=True)
sns.kdeplot(halo2_gated_ratio, color='lightgrey', shade=True)

sns.kdeplot(cdc1fl_gated_ratio, color='mediumturquoise', shade=True)
sns.kdeplot(cdc2fl_gated_ratio, color='aqua', shade=True)

sns.kdeplot(cdc1_gated_ratio, color='gold', shade=True)
sns.kdeplot(cdc2_gated_ratio, color='orange', shade=True)

plt.xlim(-1,3)
plt.xticks([-1, 0, 1, 2, 3], ("1/2", "1", "2", "4", "8"), fontsize=20)

plt.yticks([1], (""))
sns.despine(top=True, right=True)

plt.legend(title=None, labels=['control 1', 'control 2', 
                               'Cdc48 1', 'Cdc48 2', 
                              'Cdc48(1-155) 1', 'Cdc48(1-155) 2'],
                               bbox_to_anchor=(1.05, 1), loc=2, fontsize=18, framealpha=0.0)

plt.axvline(0.32, 0,1, linestyle='--', color='turquoise')
plt.axvline(1.58, 0,1, linestyle='--', color='orange')

#plt.savefig("Cdc48_Flv1-155.png", format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# initialise data of lists: Mrn1 only data 
import pandas as pd
QPCR = {'replicate':['rep 1', 'rep 2', 'rep 3', 
                    'rep 1', 'rep 2', 'rep 3'], 
           'fold change':[0.946, 0.993, 1.07, 
                          1.41, 1.67, 1.47], 
          'gene':['control', 'control', 'control',
              'Cdc48(1-155)', 'Cdc48(1-155)', 'Cdc48(1-155)']} 
  
# Creates pandas DataFrame. 
dfQPCR = pd.DataFrame(QPCR) 
  
# print the data 
dfQPCR
# Out:
#   replicate  fold change          gene
# 0     rep 1        0.946       control
# 1     rep 2        0.993       control
# 2     rep 3        1.070       control
# 3     rep 1        1.410  Cdc48(1-155)
# 4     rep 2        1.670  Cdc48(1-155)
# 5     rep 3        1.470  Cdc48(1-155)

# %%
import seaborn as sns
sns.set_style("ticks")
ax = sns.catplot(x="gene", y="fold change", hue="replicate", data=dfQPCR,
                kind="bar", palette=["whitesmoke","gainsboro", "lightgrey"], legend=False)

plt.xlabel("Cdc48(1-155) tethered to YFP", fontsize=22)
plt.ylabel("Relative YFP mRNA abundance", fontsize=22)

plt.yticks([0, 0.5, 1.0, 1.5], ("0", "0.5", "1.0", "1.5"), fontsize=18)
plt.xticks(fontsize=16)
sns.despine(top=True, right=True)

plt.legend(bbox_to_anchor=(1, 0.75), loc=2, fontsize=18)


#plt.savefig("Cdc48_QPCR_grey.png", format='png',dpi=300, bbox_inches='tight')
plt.show()
